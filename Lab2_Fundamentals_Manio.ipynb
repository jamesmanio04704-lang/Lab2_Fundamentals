# %%
# [CELL 1] CONFIGURATION
ENGINEER = "Manio"
STUDENT_ID = "TUPM-26-1136"

# Derivation: Extract the last digit to act as your Logic Seed
SEED_NUM = int(STUDENT_ID[-1])

print(f"System Initialized for: {ENGINEER}")
print(f"Algorithmic Seed Value: {SEED_NUM}")
# Out:
# System Initialized for: Manio
# Algorithmic Seed Value: 6

# %%
# [CELL 2] ARCHITECTURE TEST
# Logic: Mathematically, 0.1 + 0.2 = 0.3. Does the computer agree?
actual = 0.1 + 0.2

print(f"Python stores: {actual}")

if actual == 0.3:
    print("Result: Perfect Match")
else:
    print("Result: PRECISION ERROR (Binary Artifact)")
# Out:
# Python stores: 0.30000000000000004
# Result: PRECISION ERROR (Binary Artifact)

# %%
# [CELL 3] ASCII INSPECTION
first_letter = ENGINEER[0]
byte_val = ord(first_letter) # Convert Char to Integer Memory Code

print(f"Character: {first_letter}")
print(f"ASCII Value: {byte_val}")
print(f"Next in Sequence: {chr(byte_val + 1)}")
# Out:
# Character: M
# ASCII Value: 77
# Next in Sequence: N

# %%
# [CELL 4] SANITIZATION
raw_in = input("Enter Name (add messy spaces): ")
# Pipeline: Strip whitespace -> Convert to Uppercase
clean_in = raw_in.strip().upper()
print(f"Original: '{raw_in}' | Cleaned: '{clean_in}' ")
# Out:
# Original: 'manio' | Cleaned: 'MANIO'

# %%
# [CELL 5] DATA EXISTENCE
user_input = input("Press Enter (leave empty) or type data: ")

# Pythonic Way: An empty string is treated as False.
if user_input:
    print(f"Data Detected: {user_input}")
else:
    print("ALERT: No data stream detected.")
# Out:
# Data Detected: enter

# %%
# [CELL 6] SLICING & PARSING
campus = STUDENT_ID[0:4]
unique_id = STUDENT_ID[8:]

# Tokenization: Split string into a List based on delimiter
tokens = STUDENT_ID.split("-")

print(f"Campus Code: {campus}")
print(f"Unique Sequence: {unique_id}")
print(f"Token List: {tokens}")
# Out:
# Campus Code: TUPM
# Unique Sequence: 1136
# Token List: ['TUPM', '26', '1136']

# %%
# [CELL 7] MODULO OPERATOR
# Logic: Check if Seed Number is Even or Odd using %

if SEED_NUM % 2 == 0:
    priority = "LOW (Even Seed)"
else:
    priority = "HIGH (Odd Seed)"
print(f"System Priority: {priority}")
# Out:
# System Priority: LOW (Even Seed)

# %%
# [CELL 8] DYNAMIC LIMITS
limit = (SEED_NUM * 10) + 20
print(f"--- SAFETY LIMIT: {limit} ---")

val = int(input("Enter Sensor Reading: "))

if val > limit:
    print("ALERT: Over Limit")
elif val < 5:
    print("ALERT: Low Signal")
else:
    print("STATUS: Nominal")
# Out:
# --- SAFETY LIMIT: 80 ---
# STATUS: Nominal

# %%
# [CELL 9] ROBUST INPUT (Exception Handling)
try:
    voltage = int(input("Enter Voltage (Numeric): "))
    print(f"Voltage Captured: {voltage}V")
except ValueError:
    print("SYSTEM ERROR: Input must be numeric. Resetting to 0.")
    voltage = 0
print(f"System continues... Current Voltage: {v

oltage}")
# Out:
# Voltage Captured: 5V
# System continues... Current Voltage: 5

# %%
# [CELL 10] LOGIC GATES
has_power = False

if has_power and (10 / 0 == 0):
    print("System is On")
else:
    print("System Off (Short-Circuit Triggered)")
# Out:
# System Off (Short-Circuit Triggered)

# %%
# [CELL 11] FOR LOOP
loops = SEED_NUM + 3
print(f"--- RUNNING {loops} CYCLES ---")

for i in range(1, loops + 1):
    print(f"Cycle {i}/{loops} ... Complete")
# Out:
# --- RUNNING 9 CYCLES ---
# Cycle 1/9 ... Complete
# Cycle 2/9 ... Complete
# Cycle 3/9 ... Complete
# Cycle 4/9 ... Complete
# Cycle 5/9 ... Complete
# Cycle 6/9 ... Complete
# Cycle 7/9 ... Complete
# Cycle 8/9 ... Complete
# Cycle 9/9 ... Complete

# %%
# [CELL 12] NESTED LOOPS
rows = int(tokens[2][0])

cols = int(tokens[2][-1])
print(f"Generating {rows}x{cols} Matrix:")

for r in range(rows):
    for c in range(cols):
        print("#", end=" ")
    print()
# Out:
# Generating 1x6 Matrix:
# # # # # # #

# %%
# [CELL 13] INPUT VALIDATION
while True:
    pwd = input("Type 'ADMIN' to exit: ")
    if pwd == "ADMIN":
        print("Unblocked. ")
        break
    else:
        print('Access Denied.')
# Out:
# Access Denied.
# Access Denied.
# Access Denied.
# Unblocked.

# %%
# [CELL 14] FORENSIC HASH CALCULATION

A = byte_val
B = SEED_NUM
C = loops

verification_hash = (A * B) - C

print(f'User: {ENGINEER}')
print(f'Forensic Signature: {verification_hash}')
# Out:
# User: Manio
# Forensic Signature: 453

# %%
# [EXERCISE 1] SENSOR MONITORING SYSTEM
SURNAME = "MANIO"
SEED_NUM = 3  # Replace with your actual SEED_NUM from Task 4

# 1. Generate unique sensor data based on surname length and SEED_NUM
raw_readings = [f"{ord(SURNAME[0])}", "invalid_str", f"{SEED_NUM * 15}", "200", f"{SEED_NUM * 5 - 10}"]
operating_limit = (SEED_NUM * 10) + 20

valid_count = 0
invalid_count = 0
results = []

print("=== SENSOR DATA PROCESSING LOG ===")
for entry in raw_readings:
    try:
        val = int(entry)
        if val < 0:
            status = "INVALID (Negative Reading)"
            invalid_count += 1
        elif val > operating_limit:
            status = "CRITICAL (Over Limit)"
            valid_count += 1
        else:
            status = "NOMINAL (Within Range)"
            valid_count += 1
        results.append((entry, status))
        print(f"Reading '{entry}': {status}")
    except ValueError:
        invalid_count += 1
        results.append((entry, "INVALID (Non-Numeric)"))
        print(f"Reading '{entry}': INVALID (Non-Numeric)")

print("\n=== SUMMARY REPORT ===")
print(f"Total Readings Processed: {len(raw_readings)}")
print(f"Valid Readings: {valid_count} | Invalid Readings: {invalid_count}")
# Out:
# === SENSOR DATA PROCESSING LOG ===
# Reading '77': CRITICAL (Over Limit)
# Reading 'invalid_str': INVALID (Non-Numeric)
# Reading '45': NOMINAL (Within Range)
# Reading '200': CRITICAL (Over Limit)
# Reading '5': NOMINAL (Within Range)
#
# === SUMMARY REPORT ===
# Total Readings Processed: 5
# Valid Readings: 4 | Invalid Readings: 1

# %%
# [EXERCISE 2] SIGNAL DIAGNOSTIC SYSTEM
SURNAME = "MANIO"
SEED_NUM = 3

# 1. Generate raw signal string using SURNAME and SEED_NUM
raw_signal = f"  Sig-{SURNAME}-{SEED_NUM * 107}#!  "

# 2. Normalize signal (strip whitespace and uppercase)
processed_signal = raw_signal.strip().upper()

digits = 0
letters = 0
specials = 0

print(f"Raw Signal: '{raw_signal}'")
print(f"Processed Signal: '{processed_signal}'")
print("\n--- Character Analysis ---")

for char in processed_signal:
    if char.isalpha():
        letters += 1
        ctype = "Letter"
    elif char.isdigit():
        digits += 1
        ctype = "Digit"
    else:
        specials += 1
        ctype = "Special Symbol/Delimiter"
    print(f"Char: '{char}' -> ASCII: {ord(char)} | Type: {ctype}")

# Signal Classification based on composition
if digits > letters:
    classification = "Telemetry / Numerical Data Stream"
else:
    classification = "Command / Text Protocol"

print(f"\nSignal Classification: {classification}")
# Out:
# Raw Signal: '  Sig-MANIO-321#!  '
# Processed Signal: 'SIG-MANIO-321#!'
#
# --- Character Analysis ---
# Char: 'S' -> ASCII: 83 | Type: Letter
# Char: 'I' -> ASCII: 73 | Type: Letter
# Char: 'G' -> ASCII: 71 | Type: Letter
# Char: '-' -> ASCII: 45 | Type: Special Symbol/Delimiter
# Char: 'M' -> ASCII: 77 | Type: Letter
# Char: 'A' -> ASCII: 65 | Type: Letter
# Char: 'N' -> ASCII: 78 | Type: Letter
# Char: 'I' -> ASCII: 73 | Type: Letter
# Char: 'O' -> ASCII: 79 | Type: Letter
# Char: '-' -> ASCII: 45 | Type: Special Symbol/Delimiter
# Char: '3' -> ASCII: 51 | Type: Digit
# Char: '2' -> ASCII: 50 | Type: Digit
# Char: '1' -> ASCII: 49 | Type: Digit
# Char: '#' -> ASCII: 35 | Type: Special Symbol/Delimiter
# Char: '!' -> ASCII: 33 | Type: Special Symbol/Delimiter
#
# Signal Classification: Command / Text Protocol

# %%
# [EXERCISE 3] ACCESS AUTHENTICATION SYSTEM
SURNAME = "MANIO"
SEED_NUM = 3

# Generate password and attempt limit
target_password = f"{SURNAME}{SEED_NUM * 10}".upper()
attempt_limit = SEED_NUM + 2

# Simulated login attempts
simulated_inputs = ["ADMIN", "WRONG123", target_password]

attempts = 0
authenticated = False

print(f"Target Security Credential: {target_password}")
print(f"Allowed Attempts Limit: {attempt_limit}\n")

for pwd_try in simulated_inputs:
    attempts += 1
    normalized_try = pwd_try.strip().upper()
    print(f"Attempt {attempts}/{attempt_limit}: Entered '{normalized_try}'")
    
    if normalized_try == target_password:
        authenticated = True
        print(">>> ACCESS GRANTED: Security Clearance Verified.")
        break
    else:
        print(">>> ACCESS DENIED: Incorrect Credential.")
    
    if attempts >= attempt_limit:
        print(">>> SYSTEM LOCKOUT: Maximum attempt threshold reached.")
        break

final_state = "UNLOCKED" if authenticated else "LOCKED / SUSPENDED"
print(f"\nFinal System State: {final_state}")
# Out:
# Target Security Credential: MANIO30
# Allowed Attempts Limit: 5
#
# Attempt 1/5: Entered 'ADMIN'
# >>> ACCESS DENIED: Incorrect Credential.
# Attempt 2/5: Entered 'WRONG123'
# >>> ACCESS DENIED: Incorrect Credential.
# Attempt 3/5: Entered 'MANIO30'
# >>> ACCESS GRANTED: Security Clearance Verified.
#
# Final System State: UNLOCKED
